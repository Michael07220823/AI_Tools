# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import plot_model

print(tf.keras.__version__)

model = Sequential()
model.add(Dense(64, input_dim = 32, activation = "relu"))
model.add(Dense(64, activation = "relu"))
model.add(Dense(10, activation = "softmax"))
model.compile(loss = keras.losses.categorical_crossentropy,
              optimizer = keras.optimizers.SGD(lr = 0.01, momentum = 0.9, nesterov = True),
              metrics=['accuracy'])


import numpy as np

data = np.random.random((1000, 32))
labels = np.random.random((1000, 10))

val_data = np.random.random((100, 32))
val_labels = np.random.random((100, 10))

model.fit(data, labels, epochs = 10, batch_size = 32, 
          validation_data=(val_data, val_labels))


tf.keras.utils.plot_model(model, to_file='model.png')
# Out:
# 2.2.4-tf
# Train on 1000 samples, validate on 100 samples
# Epoch 1/10
# 1000/1000 [==============================] - 0s 260us/sample - loss: nan - acc: 0.0970 - val_loss: nan - val_acc: 0.1000
# Epoch 2/10
# 1000/1000 [==============================] - 0s 55us/sample - loss: nan - acc: 0.0860 - val_loss: nan - val_acc: 0.1000
# Epoch 3/10
# 1000/1000 [==============================] - 0s 50us/sample - loss: nan - acc: 0.0860 - val_loss: nan - val_acc: 0.1000
# Epoch 4/10
# 1000/1000 [==============================] - 0s 49us/sample - loss: nan - acc: 0.0860 - val_loss: nan - val_acc: 0.1000
# Epoch 5/10
# 1000/1000 [==============================] - 0s 53us/sample - loss: nan - acc: 0.0860 - val_loss: nan - val_acc: 0.1000
# Epoch 6/10
# 1000/1000 [==============================] - 0s 50us/sample - loss: nan - acc: 0.0860 - val_loss: nan - val_acc: 0.1000
# Epoch 7/10
# 1000/1000 [==============================] - 0s 49us/sample - loss: nan - acc: 0.0860 - val_loss: nan - val_acc: 0.1000
# Epoch 8/10
# 1000/1000 [==============================] - 0s 49us/sample - loss: nan - acc: 0.0860 - val_loss: nan - val_acc: 0.1000
# Epoch 9/10
# 1000/1000 [==============================] - 0s 50us/sample - loss: nan - acc: 0.0860 - val_loss: nan - val_acc: 0.1000
# Epoch 10/10
# 1000/1000 [==============================] - 0s 68us/sample - loss: nan - acc: 0.0860 - val_loss: nan - val_acc: 0.1000
