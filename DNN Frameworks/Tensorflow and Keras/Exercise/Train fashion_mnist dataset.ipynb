# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np

print(keras.__version__)
# Out:
# 2.3.0-tf

# %% [markdown]
# # 載入Fashion_mnist資料集

# %%
fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
print(train_images.shape)
print(test_images.shape)
print(train_labels.shape)
print(test_labels.shape)
# Out:
# ...
# 4423680/4422102 [==============================] - 0s 0us/step
# (60000, 28, 28)
# (10000, 28, 28)
# (60000,)
# (10000,)

# %% [markdown]
# # 建立標籤

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# # 建立、編譯、訓練、評估模型

# %%
model = keras.models.Sequential([
                                 keras.layers.Flatten(input_shape = (28, 28)),
                                 keras.layers.Dense(128, activation = "relu"),
                                 keras.layers.Dropout(0.2),
                                 keras.layers.Dense(10, activation = "softmax")
])

model.compile(optimizer = "adam",
              loss = "sparse_categorical_crossentropy",
              metrics = ["accuracy"]
)

model.fit(train_images, train_labels, epochs = 10, validation_data = (test_images, test_labels))
test_loss, test_acc = model.evaluate(test_images, test_labels)
print("[INFO] test_loss:%.4f, test_acc:%.4f" % (test_loss, test_acc * 100))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.6941 - accuracy: 0.6004 - val_loss: 0.7822 - val_accuracy: 0.6970
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.9351 - accuracy: 0.6380 - val_loss: 0.7595 - val_accuracy: 0.7039
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.8988 - accuracy: 0.6498 - val_loss: 0.7493 - val_accuracy: 0.7164
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.8554 - accuracy: 0.6771 - val_loss: 0.6582 - val_accuracy: 0.7467
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.8025 - accuracy: 0.6920 - val_loss: 0.6174 - val_accuracy: 0.7688
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.7908 - accuracy: 0.6996 - val_loss: 0.6369 - val_accuracy: 0.7447
# Epoch 7/10
# ...

# %% [markdown]
# # 預測

# %%
predictions = model.predict(test_images)
print(predictions[0])
print("預測的值是:", np.argmax(predictions[0]))
print("實際的值是:",test_labels[0])
# Out:
# [0.0000000e+00 2.1613216e-35 0.0000000e+00 2.2157635e-32 0.0000000e+00
#  4.6404041e-02 0.0000000e+00 1.1867776e-02 2.5397807e-20 9.4172823e-01]
# 預測的值是: 9
# 實際的值是: 9

# %% [markdown]
# # 參考來源[Basic classification: Classify images of clothing](https://www.tensorflow.org/tutorials/keras/classification)
