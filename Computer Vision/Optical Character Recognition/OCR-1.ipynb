# %% [markdown]
# # Optical Charater Recognition

# %% [markdown]
# ## 範例一－中文歌譜

# %%
from PIL import Image
import pytesseract as pytess
import matplotlib.pyplot as plt

img = Image.open("F:/Github/AI_Tools/Computer Vision/Optical Character Recognition/images/song_sheet/隱形的翅膀.png")
plt.figure("Song sheet")
plt.imshow(img)
plt.show()

print(pytess.image_to_string(img, lang='chi_tra'))
# Out:
#
#
# 張韶涵-隱形的媽膀
#
# 1i=C 全
# =72           (根遞張韶涵演唱音頻記譜)       王 雅 君 詞曲
# 崔南印象 制譜
# 人一一 ~/3、ˋ         圖
# (@o9oas|i-iize|.@5-19544s到[|s--9191色4鋪|
#
# 2121-195 43 2.1711--)51卓3353211111655 51|
#
# 7每一“次 都在徘徊 孤單中堅 強,每一
#
# 名(不才 想 他位 擁有 美而的太 站, 我看
# 5                  55565|32126 56|
# 炎 記生人  及全 也不 過凋 光, 我外 放牧一 一直有雙 隱形的翅膀, 帶我
# 見 每天的夕陽 也會 有變 化,我知 道 我一直有以 隱形的翅膀, 帶我
#
# [了   | 2
# -3231|11-051:|i-035|i.i765|16i321 11|
# 狼
#
# GS
# 局
# G局
#
#
#
#
#
# 1
# % 《過絕望。 2.不去
# 和    ,
#
#
#
# 給我希       望。  我終 於 看到所有 夢想都開花,追逐
# 1i653212|2-035|i.i7 65|6i321 11|
# 的年輕歌聲多  亮。 我終 說 革翔,用心 凝望不害怕,哪里
#
# 53 21|1-0 (035|15.55 5ii ii2 | i.5ii-|05443 2221 11
#
#
#
#
#
# 務灼勞遙天/- Mo/o釣放紡每縱池說。-///汐泌鄉光六滬六 222有52752
# 學22交馮范字說災泛汪次goo0727coz72/5oace/762胞      C00 -.527777627

# %% [markdown]
# ## 範例二－英文文章

# %%
import cv2
import pytesseract as pytess
import matplotlib.pyplot as plt

img = cv2.imread("F:/Github/AI_Tools/Computer Vision/Optical Character Recognition/images/article/article-2.jpg")
plt.figure("english article")
plt.imshow(img)
plt.show()

print(pytess.image_to_string(img, lang='eng'))
# Out:
# B.J.Pot.S, 2, 83-108
# Printed in Great Britain
#
# Review Article: Policy Analysis
# H. HUGH HECLO*
#
# The analysis of public policy is one of the most rapidly expanding and least well-
# mapped areas of political science. The renewed fashionability of the subject is
# attested to by the founding in 1970 of a sophisticated new journal, Policy Sciences,
# the opening of the first graduate programs granting doctorates in public policy,
# and a vast proliferation of publications.! Modern political scientists, we are told,
# ‘cry out a concern for policy relevance’.? What follows is not a definitive survey
# of all policy studies but an attempt to explicate several of the most important
# approaches. It may be worthwhile to pause and take stock of where we have got
# to before the tide of articles, books and doctorates in public policy rises too far
# above our shoulders.
#
# One cannot take a step into the field without immediately sinking deep in
# hoary questions concerning the normative stance of the scholar. I should there-
# fore begin by warning that this article does not deal with the question which
# typically preoccupies any general discussion of public policy and political science,
# i.e., what role political science can or should play in policy-making. To my mind
# this argument has not advanced much beyond the point at which Weber left it,?
# although one can be amused by the self-flattery involved in the unspoken premise
# that political scientists would in fact have something to contribute if only they
# decided to be ‘policy relevant’. At times, it seems a mock decision, with all the
# vain drama of an impotent man agitating his conscience as to whether or not to
# enter the brothel. One mark of this sterility is the fact that assessments of the state
# of policy studies are frequently treated as synonymous with the problem of a
# value-free political science — to the detriment of other topics which might profit-
# ably be discussed. Here we shall not be concerned with whether political scientists
#
# * Department of Government, University of Essex.
#
# ! Edward S. Quade, ed., Policy Sciences (New York: American Elsevier Publishing Company,
# 1970). At last count (1970), there were seven US universities with doctoral programs specifically
# in public policy; in Britain as far as I can tell, there are several undergraduate classes and two
# seminars in Masters programs devoted to policy studies. As examples of the flood of publication,
# one may cite, in ascending order of political ‘involvement’: Raymond Bauer and K. Gergen,
# The Study of Policy Formation (New York: Free Press, 1968); the 1966, 1967 conferences of the
# United States SSRC Committee on Government and Legal Processes; and the Caucus for a
# New Political Science Association. For attempts to develop approaches to practical policy
# advice in political science, see Warren Ichman and Norman Uphoff, The Political Economy of
# Change (Berkeley: UCLA Press, 1969); Yehizel Dror, ‘Policy Analysts’, Public Administration
# Review, 27 (1967), 197-203. The policy emphasis has also spread to new government textbooks,
# as in J. M. and W. C. Mitchell's Political Analysis and Public Policy (Chicago: Rand-McNally
# and Co., 1969).
#
# ? Ithiel de Sola Pool, ed., Contemporary Political Science (New York: McGraw-Hill, 1967),
# P. xii.
#
# +The discussion is summarized in Arnold Brecht, Political Theory: The Foundations of
# Twentieth Century Political Thought (Princeton: Princeton University Press, 1959).

# %% [markdown]
# ## 範例三－數學方程式

# %%
import cv2
import pytesseract as pytess
import matplotlib.pyplot as plt

img = cv2.imread("F:/Github/AI_Tools/Computer Vision/Optical Character Recognition/images/math/formula-1.jpg")
plt.figure("math")
plt.imshow(img)
plt.show()

print(pytess.image_to_string(img, lang='eng'))
# Out:
# Important Algebraic Formulas
# (a+ b)* = a*+ b? + 2ab
# (a— by’ = a’? + b? — 2ab
# a* — b? = (a+ b)(a—b)
# a? +b? = (a+ b)*—2ab or a*+b*=(a—b)*+2ab
# a? + b? = (a+ b)(a* —ab+b*) = (a+b)? — 3ab(a+ b)
# a? — b? = (a— b)(a? +. ab+ 5b") = (a—b)? + 3ab(a— b)
# 2(a? + b?) = (a+ b)2+ (a—b)?
# (a+ b)* —(a— b)* =4ab
# a*+ b* = (a+ b)(a— b)[(a+ b)* —2ab]
# (a— b)* = (a+ b)* —4ab
# (a+ b)* = (a—b)* +4ab
# at + b* = [(a + b)? — 2ab]? — 2(aby*
# (a+ b+c)? = a*+b?4+¢? + 2ab+ 2bc+2ca
# (a+ b—c)* = a*+b? 4 c? + 2ab— 2be—2ca
# (a—b—c)? = a*+b? + c? — 2ab+ 2bc—2ca
# a?+b? +c?— 3abe=(a+ b+ c)(a?+b? + c* —ab— be-ca)
# a*+ a7b?+b* = (a? + ab + b”)(a* — ab+ b*
#
# a*+ a?24+1=(a?+a+ 1)(a*-—a+1)
# ifat+b+c=Othen a?+b?+c? = 3abc
# a® — b® = (a* + b*)(a* + b”)(a+ b)(a— Bb)
